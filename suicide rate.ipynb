# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
print(os.listdir("./dataset"))
# Out:
# ['.DS_Store', 'master.csv']

# %%
data = pd.read_csv('./dataset/master.csv')
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
# renomear as colunas
data.columns = ['country', 'year', 'sex', 'age', 'suicides_no', 'population',
               'suicidesper100kpop', 'country-year', 'HDI for year',
               'gdp_for_year_dollars', 'gdp_per_capita_dollars', 'generation']

# %%
# transformar em números inteiros
data['gdp_for_year_dollars'] = data['gdp_for_year_dollars'].str.replace(',','').astype(int)

# %%
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicidesper100kpop country-year  HDI for year  gdp_for_year_dollars  \
# 0                6.71  Albania1987           NaN            2156624900
# 1                5.19  Albania1987           NaN            2156624900
# 2                4.83  Albania1987           NaN            2156624900
# 3                4.59  Albania1987           NaN            2156624900
# 4                3.28  Albania1987           NaN            2156624900
#
#    gdp_per_capita_dollars       generation
# 0                     796     Generation X
# 1                     796           Silent
# ...

# %%
for ft in data.columns.values:
    print(ft, end = "|")
# Out:
# country|year|sex|age|suicides_no|population|suicidesper100kpop|country-year|HDI for year|gdp_for_year_dollars|gdp_per_capita_dollars|generation|

# %%
# for ft in data.columns.values:
#     print(ft.center(30, '-'))
#     print(data[ft].describe())

data.describe()
# Out:
#                year   suicides_no    population  suicidesper100kpop  \
# count  27820.000000  27820.000000  2.782000e+04        27820.000000
# mean    2001.258375    242.574407  1.844794e+06           12.816097
# std        8.469055    902.047917  3.911779e+06           18.961511
# min     1985.000000      0.000000  2.780000e+02            0.000000
# 25%     1995.000000      3.000000  9.749850e+04            0.920000
# 50%     2002.000000     25.000000  4.301500e+05            5.990000
# 75%     2008.000000    131.000000  1.486143e+06           16.620000
# max     2016.000000  22338.000000  4.380521e+07          224.970000
#
#        HDI for year  gdp_for_year_dollars  gdp_per_capita_dollars
# count   8364.000000          2.782000e+04            27820.000000
# mean       0.776601          4.455810e+11            16866.464414
# std        0.093367          1.453610e+12            18887.576472
# min        0.483000          4.691962e+07              251.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country                   27820 non-null object
# year                      27820 non-null int64
# sex                       27820 non-null object
# age                       27820 non-null object
# suicides_no               27820 non-null int64
# population                27820 non-null int64
# suicidesper100kpop        27820 non-null float64
# country-year              27820 non-null object
# HDI for year              8364 non-null float64
# gdp_for_year_dollars      27820 non-null int64
# gdp_per_capita_dollars    27820 non-null int64
# generation                27820 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.5+ MB

# %%
# remover a coluna HDI pq tem dados incompletos e a country-year pq é irrelevante

# colocando os dados no dataframe data_n, preservando os originais no data
data_n = data.drop(['HDI for year', 'country-year'], axis=1)
data_n.head(3)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
#
#    suicidesper100kpop  gdp_for_year_dollars  gdp_per_capita_dollars  \
# 0                6.71            2156624900                     796
# 1                5.19            2156624900                     796
# 2                4.83            2156624900                     796
#
#      generation
# 0  Generation X
# 1        Silent
# 2  Generation X

# %%
data_n.describe()
# Out:
#                year   suicides_no    population  suicidesper100kpop  \
# count  27820.000000  27820.000000  2.782000e+04        27820.000000
# mean    2001.258375    242.574407  1.844794e+06           12.816097
# std        8.469055    902.047917  3.911779e+06           18.961511
# min     1985.000000      0.000000  2.780000e+02            0.000000
# 25%     1995.000000      3.000000  9.749850e+04            0.920000
# 50%     2002.000000     25.000000  4.301500e+05            5.990000
# 75%     2008.000000    131.000000  1.486143e+06           16.620000
# max     2016.000000  22338.000000  4.380521e+07          224.970000
#
#        gdp_for_year_dollars  gdp_per_capita_dollars
# count          2.782000e+04            27820.000000
# mean           4.455810e+11            16866.464414
# std            1.453610e+12            18887.576472
# min            4.691962e+07              251.000000
# 25%            8.985353e+09             3447.000000
# ...

# %%
sorted(set(data_n.year.tolist()))
# Out:
# [1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
data.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicidesper100kpop', 'country-year', 'HDI for year',
#        'gdp_for_year_dollars', 'gdp_per_capita_dollars', 'generation'],
#       dtype='object')

# %%
df = data

# %%
# Out:
# str

# %%
d = df.to_json(orient='records')

# %%
import json
js = json.loads(d)

# %%
for el in js:
    print(el)
    break
# Out:
# {'country': 'Albania', 'year': 1987, 'sex': 'male', 'age': '15-24 years', 'suicides_no': 21, 'population': 312900, 'suicidesper100kpop': 6.71, 'country-year': 'Albania1987', 'HDI for year': None, 'gdp_for_year_dollars': 2156624900, 'gdp_per_capita_dollars': 796, 'generation': 'Generation X'}

# %%
js[2]
# Out:
# {'country': 'Albania',
#  'year': 1987,
#  'sex': 'female',
#  'age': '15-24 years',
#  'suicides_no': 14,
#  'population': 289700,
#  'suicidesper100kpop': 4.83,
#  'country-year': 'Albania1987',
#  'HDI for year': None,
#  'gdp_for_year_dollars': 2156624900,
#  'gdp_per_capita_dollars': 796,
#  'generation': 'Generation X'}
